# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from spacy.lang.fa import stop_words
from string import punctuation, printable, digits
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, TransformerMixin

import pandas as pd
import re
from nltk.tokenize import RegexpTokenizer


from __future__ import unicode_literals
from hazm import *
stemmer = Stemmer()

# %%
df = pd.read_csv("data-q2/train_users.csv")

df['type'] = 'train'

df = pd.read_csv("data-q2/train_users.csv")

df['type'] = 'train'

# %%
df.head()
# Out:
#    id    title                                            comment  \
# 0   0      NaN       مثل بقیه محصولات الکل دار پوست رو خشک نمیکنه
# 1   1  Redmi 8  با این مبلغ اگه امکانات و ارزش خرید واستون مهم...
# 2   2     عالی  خوبه فقط کج و کوله بدستم رسید ولی پسرم خیلی خو...
# 3   3      NaN  در کل خوب بود ولی متاسفانه درب محصول شکسته بود...
# 4   4      NaN  من که خیلی باهاش حال کردم فقط من که همیشه L می...
#
#                                           advantages       disadvantages  \
# 0                                                NaN                 NaN
# 1  ["رم4\r","قیمت نسبت به سایر برندها\r","طراحی و...  ["نداشتن هندزفری"]
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#                                     title_fa_product        title_fa_category  \
# 0  ژل ضد عفونی کننده دست شون مدل Aloevera حجم 300...            ضدعفونی کننده
# 1  گوشی موبایل شیائومی مدل Redmi 8 M1908C3IG دو س...              گوشی موبایل
# 2                   ماسک کودک طرح سگ نگهبان مدل رابل                ایفای نقش
# 3  مایع ضدعفونی کننده میوه و سبزیجات من مدل WT حج...       ضدعفونی کننده سطوح
# 4       تی شرت آستین کوتاه مردانه باینت کد 323-1 btt  تی شرت و پولوشرت مردانه
#
#    is_buyer  verification_status   rate   type
# 0         1                    1  100.0  train
# 1         1                    1   80.0  train
# 2         1                    1  100.0  train
# 3         1                    1   70.0  train
# 4         1                    1   72.0  train

# %%
df.drop([ 'title_fa_product' , 'title_fa_category' ],inplace=True,axis=1)

df.fillna(" ",inplace=True)
# df['text'] = df['text'].apply(lambda x : x.replace('nan' , ' '))

df['title'] = df['title'].astype(str)
df['comment'] = df['comment'].astype(str)
df['advantages'] = df['advantages'].astype(str)
df['disadvantages'] = df['disadvantages'].astype(str)

# %%
def preprocess(text):
    pattern = r'[\u0600-\u06FF\u0698\u067E\u0686\u06AF]+'
    tokenizer = RegexpTokenizer(pattern)
    text = tokenizer.tokenize(text)
    text = ' '.join(text)
    return text

# %%
df['title'] = df['title'].apply(lambda x : preprocess(x))
df['comment'] = df['comment'].apply(lambda x : preprocess(x))
df['advantages'] = df['advantages'].apply(lambda x : preprocess(x))
df['disadvantages'] = df['disadvantages'].apply(lambda x : preprocess(x))
